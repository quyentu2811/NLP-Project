# %%
# !rm -r NLP-Project

# %%
# !git clone -b master "https://github.com/quyentu2811/NLP-Project.git"

# %%
# !bash "/kaggle/working/NLP-Project/setup.sh"

# %%
# !python /kaggle/working/NLP-Project/run_training.py\
    --checkpoint "google/flan-t5-xxl"\
    --datapath "knkarthick/dialogsum"\
    --huggingface_hub_token "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"\
    --wandb_token "c456a83d581dce980c77ae1bf7613173858779c8"\
    --output_dir "flant5-xxl-finetuning"\
    --overwrite_output_dir True\
    --run_name "flant5-xxl-finetuning-run"\
    --num_train_epochs 6\
    --per_device_train_batch_size 4\
    --per_device_eval_batch_size 4\
    --logging_steps 250\
    --gradient_accumulation_steps 4\
    --save_total_limit 1\
    --evaluation_strategy "steps"\
    --metric_for_best_model "eval_loss"\
    --save_strategy "epoch"
